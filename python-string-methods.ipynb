# %% [markdown]
# <a href="https://www.kaggle.com/code/vedatgul/python-string-methods?scriptVersionId=123551244" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # What are Useful Python String Methods

# %% [markdown]
# **Useful python string methods and examples are as follows. The phrase "Hello AI World" is used in the examples.**

# %%
# lower(): Converts a string into lower case

"Hello AI World".lower()
# Out:
# 'hello ai world'

# %%
# upper(): Converts a string into upper case

"Hello AI World".upper()
# Out:
# 'HELLO AI WORLD'

# %%
# partition(): Returns a tuple where the string is parted into three parts

word = "Hello AI World"
word.partition("Hello")
# Out:
# ('', 'Hello', ' AI World')

# %%
# replace(): Returns a string where a specified value is replaced with a specified value

word = "Hello AI World"
word.replace("AI", "Python")
# Out:
# 'Hello Python World'

# %%
# find(): Searches the string for a specified value and returns the position of where it was found
word = "Hello AI World"
word.find("AI")
# Out:
# 6

# %%
# len(): Returns the number of characters of the string expression.
word = "Hello AI World"
len(word)
# Out:
# 14

# %%
# title(): Converts the first character of each word to upper case
word = "hello ai world"
word.title()
# Out:
# 'Hello Ai World'

# %%
# swapcase(): Swaps cases, lower case becomes upper case and vice versa
word = "Hello AI World"
word.swapcase()
# Out:
# 'hELLO ai wORLD'

# %%
#join(): Converts the elements of an iterable into a string
word = "Hello AI World"
"-".join(word)
# Out:
# 'H-e-l-l-o- -A-I- -W-o-r-l-d'

# %%
# split(): Splits the string at the specified separator, and returns a list
word = "Hello AI World"
word.split()
# Out:
# ['Hello', 'AI', 'World']
